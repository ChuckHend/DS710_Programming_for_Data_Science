# %% [markdown]
# # Problem 1(a).  Reading Amazon Reviews.
#
# In this problem, we will analyze Amazon reviews to determine what characteristics make them most helpful.
#
# Download the file of Amazon gourmet food reviews from the [Stanford Large Network Dataset Collection](https://snap.stanford.edu/data/web-FineFoods.html).   (Your computer may already have a utility installed that can unzip the archive as a text file; if not, [7-zip](http://www.7-zip.org/) is a useful utility for Windows. You can also use an online utility by doing a web search for: ``open .gz files online``.)
#
# Create a pandas DataFrame object with the following entries for each review:
#
# * Product ID
# * Number of people who voted this review helpful
# * Total number of people who rated this review
# * Rating of the product
# * Text of the review
#
# For the second and third of these, the information will be given in the file as ```1/5```, which would correspond to 1 vote for helpful out of 5 people who rated the review.

# %%
import pandas as pd
import numpy as np

# %%
fileLoc = '/Users/ahendel1/Downloads/finefoods.txt'

cols = ['ProductID', 'NumHelp', 'NumReviews', 'Rating', 'Text']
dict_list = []

with open(fileLoc, encoding="ISO-8859-1") as in_file:
    
    while True:
        
        # read the line
        line = in_file.readline()
        
        if not line:
            # exit loop if we reach the end
            in_file.close()
            break
        
        if 'product/productId:' in line:
            prod_id = line.split('productId:')[1].replace('\n', '').strip()
            line = in_file.readline()
        
        if 'review/helpfulness:' in line:
            review = line.split('helpfulness:')[1].split('/')
            helpful = review[0].strip()
            total   = review[1].replace('\n', '')
            line = in_file.readline()
        
        if 'review/score:' in line:
            rating = float(line.split('score:')[1].replace('\n', '').strip())
            line = in_file.readline()
            
        if 'review/text:' in line:
            text = line.split('/text:')[1].replace('\n', '')
            dict_list.append(dict(zip(cols, [prod_id, helpful, total, rating, text])))
in_file.close()
amaz_df = pd.DataFrame(dict_list)
amaz_df
# Out:
#        NumHelp NumReviews   ProductID  Rating  \
# 0            1          1  B001E4KFG0     5.0
# 1            0          0  B00813GRG4     1.0
# 2            1          1  B000LQOCH0     4.0
# 3            3          3  B000UA0QIQ     2.0
# 4            0          0  B006K2ZZ7K     5.0
# 5            0          0  B006K2ZZ7K     4.0
# 6            0          0  B006K2ZZ7K     5.0
# 7            0          0  B006K2ZZ7K     5.0
# 8            1          1  B000E7L2R4     5.0
# 9            0          0  B00171APVA     5.0
# 10           1          1  B0001PB9FE     5.0
# 11           4          4  B0009XLVG0     5.0
# 12           1          1  B0009XLVG0     1.0
# 13           2          2  B001GVISJM     4.0
# 14           4          5  B001GVISJM     5.0
# 15           4          5  B001GVISJM     5.0
# 16           0          0  B001GVISJM     2.0
# 17           0          0  B001GVISJM     5.0
# 18           0          0  B001GVISJM     5.0
# 19           0          0  B001GVISJM     5.0
# 20           0          0  B001GVISJM     5.0
# 21           0          0  B001GVISJM     5.0
# 22           0          0  B001GVISJM     5.0
# 23           0          0  B001GVISJM     5.0
# 24           0          0  B001GVISJM     5.0
# 25           0          0  B001GVISJM     5.0
# 26           0          1  B001GVISJM     1.0
# 27           0          1  B001GVISJM     4.0
# 28           0          0  B00144C10S     5.0
# 29           1          1  B0001PB9FY     5.0
# ...        ...        ...         ...     ...
# 568424       2          2  B001FPT1WM     5.0
# 568425       2          2  B001FPT1WM     5.0
# 568426       1          1  B001FPT1WM     1.0
# 568427       1          1  B001FPT1WM     5.0
# 568428       1          1  B001FPT1WM     5.0
# 568429       1          1  B001FPT1WM     5.0
# 568430       0          0  B001FPT1WM     5.0
# 568431       0          0  B003XUL27E     1.0
# 568432       0          0  B003XUL27E     1.0
# 568433       0          0  B003XUL27E     1.0
# 568434       0          0  B003XUL27E     2.0
# 568435       0          2  B003XUL27E     2.0
# 568436      10         10  B000NY4SAG     5.0
# 568437       4          4  B000NY4SAG     5.0
# 568438       3          3  B000NY4SAG     5.0
# 568439       0          5  B000NY4SAG     4.0
# 568440       1          1  B005ZC0RRO     5.0
# 568441       0          0  B000NY8O9M     5.0
# 568442       0          0  B006T7TKZO     5.0
# 568443       0          0  B000H7K114     5.0
# 568444       3          3  B001EO7N10     5.0
# 568445       2          2  B001EO7N10     5.0
# 568446       0          0  B001EO7N10     2.0
# 568447       0          0  B001EO7N10     5.0
# 568448       0          0  B001EO7N10     5.0
# 568449       0          0  B001EO7N10     5.0
# 568450       0          0  B003S1WTCU     2.0
# 568451       2          2  B004I613EE     5.0
# 568452       1          1  B004I613EE     5.0
# 568453       0          0  B001LR2CU2     5.0
#
#                                                      Text
# 0        I have bought several of the Vitality canned ...
# 1        Product arrived labeled as Jumbo Salted Peanu...
# 2        This is a confection that has been around a f...
# 3        If you are looking for the secret ingredient ...
# 4        Great taffy at a great price.  There was a wi...
# 5        I got a wild hair for taffy and ordered this ...
# 6        This saltwater taffy had great flavors and wa...
# 7        This taffy is so good.  It is very soft and c...
# 8        Right now I'm mostly just sprouting this so m...
# 9        This is a very healthy dog food. Good for the...
# 10       I don't know if it's the cactus or the tequil...
# 11       One of my boys needed to lose some weight and...
# 12       My cats have been happily eating Felidae Plat...
# 13       good flavor! these came securely packed... th...
# 14       The Strawberry Twizzlers are my guilty pleasu...
# 15       My daughter loves twizzlers and this shipment...
# 16       I love eating them and they are good for watc...
# 17       I am very satisfied with my Twizzler purchase...
# 18       Twizzlers, Strawberry my childhood favorite c...
# 19       Candy was delivered very fast and was purchas...
# 20       My husband is a Twizzlers addict.  We've boug...
# 21       I bought these for my husband who is currentl...
# 22       I can remember buying this candy as a kid and...
# 23       I love this candy.  After weight watchers I h...
# 24       I have lived out of the US for over 7 yrs now...
# 25       Product received is as advertised.<br /><br /...
# 26       The candy is just red , No flavor . Just  pla...
# 27       I was so glad Amazon carried these batteries....
# 28       I got this for my Mum who is not diabetic but...
# 29       I don't know if it's the cactus or the tequil...
# ...                                                   ...
# 568424   I've tried several violet flavored candies in...
# 568425   This candy has a very good flavor. It is quit...
# 568426   The candy is tasty, but they totally scam you...
# 568427   I had been looking for the violet candy with ...
# 568428   these are very pricey so i only enjoy them no...
# 568429   These candies have a mild flavor, when compar...
# 568430   This product is a bit pricey for the amt. rec...
# 568431   Definitely not worth buying flavored water wi...
# 568432   I thought this soup would be more like a chil...
# 568433   I just bought this soup today at my local gro...
# 568434   This soup is mostly broth. Although it has a ...
# 568435   It is mostly broth, with the advertised 3/4 c...
# 568436   In the past, I would have to buy a large quan...
# 568437   Ammonium bicarbonate in a nice little package...
# 568438   If you haven't ever used Ammonium Bicarbonate...
# 568439   We need this for a recipe my wife is interest...
# 568440   Indie Candy's gummies are absolutely deliciou...
# 568441   Quick and easy! Had similar Gulasch in Guest ...
# 568442   This product is great.  Gives you so much ene...
# 568443   I love this tea.  I first discovered the plea...
# 568444   As a foodie, I use a lot of Chinese 5 Spice p...
# 568445   You can make this mix yourself, but the Star ...
# 568446   I had ordered some of these a few months back...
# 568447   Hoping there is no MSG in this, this tastes e...
# 568448   My only complaint is that there's so much of ...
# 568449   Great for sesame chicken..this is a good if n...
# 568450   I'm disappointed with the flavor. The chocola...
# 568451   These stars are small, so you can give 10-15 ...
# 568452   These are the BEST treats for training and re...
# 568453   I am very satisfied ,product is as advertised...
#
# [568454 rows x 5 columns]

# %% [markdown]
# # Problem 1(b).  Analyzing review text.
#
# Add columns to your DataFrame for the length of a review, the number of exclamation points in a review, and the fraction of people who rated a review helpful. You should calculate the fraction who rated a review helpful using the two columns you made in 1a, and a ratio of 1 helpful rating out of 5 total ratings should be entered as 0.2, not the string ```1/5```. If no people voted on whether a problem was helpful, the corresponding entry in your percentage helpful column should be ```NaN```.

# %%
# assign number of characters in the review
amaz_df['review_num_chars']=amaz_df.Text.apply(len)

# %%
# assign number of exlamation points in the review
amaz_df['exclams']=amaz_df.Text.apply(lambda x: x.count('!'))

# %%
# assign a fraction of number of people who found the review helpful
amaz_df['frac_helpful']=pd.to_numeric(amaz_df.NumHelp)/pd.to_numeric(amaz_df.NumReviews)

# %% [markdown]
# # Problem 1(c).  Summary statistics.
#
# How many reviews are in the data set?  What is the average length of a review (in characters)?  What is the average rating?  What is the greatest number of exclamation marks used in a single review?  Use the pandas package to answer these questions, then summarize your results in a markdown cell.

# %%
# number of reviews
amaz_df.shape[0]
# Out:
# 568454

# %%
# average length of the reviews
amaz_df.review_num_chars.mean()
# Out:
# 437.22208305333413

# %%
# average rating
amaz_df.Rating.mean()
# Out:
# 4.183198640523243

# %%
# greatest number of exclamation points in a review
amaz_df.exclams.max()
# Out:
# 84

# %% [markdown]
# ### 1c Summary
# * Reviews in the dataset = 568,454
# * Average Length of Review = 437 characters
# * Average Rating = 4.2
# * Greatest Number of Exclamation Points in a Single Review = 84

# %% [markdown]
# # Problem 1(d).  Export.
#
# Save your DataFrame as a .csv file suitable for future analysis in R.  Your .csv file should not include the review text column, as the presence of commas and quotation marks will make reading the file difficult.  You should also convert entries from ```NaN``` to the empty string before saving.

# %%
# fill nan with empty string
amaz_df.fillna('', inplace=True)
# drop the raw text column before export
amaz_df.drop('Text', axis=1, inplace=True)

# %%
amaz_df.head(1)
# Out:
#   NumHelp NumReviews   ProductID  Rating  review_num_chars  exclams  \
# 0       1          1  B001E4KFG0     5.0               264        0
#
#   frac_helpful
# 0            1

# %%
amaz_df.to_csv('finefoods_cleaned.csv', index=False)
